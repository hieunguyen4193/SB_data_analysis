# %%
import scanpy as sc
import numpy as np
import os
import anndata2ri
import pathlib
import scvelo as scv
from scipy import io
import anndata#
import pandas as pd
from tqdm import tqdm
import argparse
import sys
import re
# Activate the anndata2ri conversion between SingleCellExperiment and AnnData
anndata2ri.activate()

#Loading the rpy2 extension enables cell magic to be used
#This runs R code in jupyter notebook cells
# %load_ext rpy2.ipython

sc.settings.verbosity = 3
# sc.logging.print_versions()

import warnings
warnings.filterwarnings("ignore")
PROJECT = "SBharadwaj_20240318"
outdir = os.path.join("/media/hieunguyen/HD01/outdir/CRC1382", PROJECT)

path_to_main_src = "/home/hieunguyen/CRC1382/src_2023/SBharadwaj/deep_seq_batch/with_cell_type_annotation"
samplesheet = pd.read_csv(os.path.join(path_to_main_src, "SampleSheet_for_DGE_CellChat.CellAnnotated.csv"))
samplesheet["full_dataset_name"] = samplesheet[["PROJECT", "dataset_name"]].apply(
    lambda x: f"{x[0]}_{x[1]}", axis = 1
)
samplesheet = samplesheet[~samplesheet["full_dataset_name"].duplicated()]

# full_name = "SBharadwaj_20240318_Sample_1_4_7_8_2_5_full"

for full_name in samplesheet["full_dataset_name"].unique():
    print(f"Working on dataset {full_name}")

    #####------------------------------------------------------------#####
    ##### Read anndata
    #####------------------------------------------------------------#####
    project = samplesheet[samplesheet["full_dataset_name"] == full_name]["PROJECT"].values[0]
    dataset_name = samplesheet[samplesheet["full_dataset_name"] == full_name]["dataset_name"].values[0]
    path_to_input_s_obj = samplesheet[samplesheet["full_dataset_name"] == full_name]["path"].values[0]
    path_to_main_output = os.path.join(outdir, project, "data_analysis_with_cell_annotations")

    path_to_seurat2anndata = os.path.join(path_to_main_output, "09_output", "seurat2anndata")

    adata = sc.read_h5ad(os.path.join(path_to_seurat2anndata, '{}.h5ad'.format(full_name)))
    obsdf = adata.obs.copy()
    obsdf["barcode"] = obsdf[["barcode", "name"]].apply(lambda x: x[0].replace(f"{x[1]}_{x[1]}", f"{x[1]}"), axis = 1) 
    adata.obs.index = obsdf.barcode.values
    adata.var_names_make_unique()

    colordf = pd.read_csv(os.path.join(path_to_seurat2anndata, 'colordf_{}.csv'.format(full_name)))
    colors = colordf["color"].values
    #####------------------------------------------------------------#####
    ##### READ LOOM DATA
    #####------------------------------------------------------------#####
    path_to_loom_data = "/media/hieunguyen/HD01/outdir/CRC1382/SBharadwaj_20240318/loom"
    all_looms = [item for item in pathlib.Path(path_to_loom_data).glob("*.loom")]

    velodata_dict = dict()
    for input_loom in tqdm(all_looms):
        velodata = scv.read_loom(input_loom)
        samplename = input_loom.name.replace(".loom", "")

        new_obs = ["{}_{}_{}-1".format(samplename, samplename, item.split(":")[1].replace("x", "")) for item in velodata.obs.index]
        velodata.obs.index = new_obs
        velodata.obs["barcode"] = new_obs
        velodata.var_names_make_unique()
        pattern = re.compile('_[A|T|G|C]*-')
        new_obs = [samplename + pattern.search(string = item).group() + item.split("-")[1]
                for item in velodata.obs.index]
        velodata.obs.index = new_obs
        velodata_dict[samplename] = velodata
        velodata.var_names_make_unique()

    all_velodata = velodata_dict[list(velodata_dict.keys())[0]]
    for data in list(velodata_dict.keys())[1:]:
        all_velodata = all_velodata.concatenate(velodata_dict[data])
        
    new_obs = [item.split("-")[0] + "-1" for item in all_velodata.obs.index]
    all_velodata.obs.index = new_obs
    all_velodata.var_names_make_unique()

    #####------------------------------------------------------------#####
    ##### Data pre-processing
    #####------------------------------------------------------------#####
    merge_data = scv.utils.merge(adata, all_velodata)
    assert merge_data.obs.shape[0] == adata.obs.shape[0]
    #####------------------------------------------------------------#####
    ##### Merge data and preprocessing again
    #####------------------------------------------------------------#####
    scv.pp.filter_genes(merge_data, min_shared_counts=20)
    scv.pp.normalize_per_cell(merge_data)
    scv.pp.filter_genes_dispersion(merge_data, n_top_genes=2000)
    scv.pp.log1p(merge_data)

    scv.pp.filter_and_normalize(merge_data, min_shared_counts=20, n_top_genes=2000)
    scv.pp.moments(merge_data, n_pcs=30, n_neighbors=30)

    #####------------------------------------------------------------#####
    ##### RNA velocity inference
    #####------------------------------------------------------------#####
    scv.tl.velocity(merge_data)
    scv.tl.velocity_graph(merge_data)

    #####------------------------------------------------------------#####
    ##### save streamline RNA velocity
    #####------------------------------------------------------------#####
    scv.pl.velocity_embedding_stream(merge_data, 
                                    dpi=120, 
                                    arrow_size=2, basis = "X_umap",
                                    color="cell.annotation",
                            figsize = (12, 12), 
                            fontsize=20, 
                            legend_fontsize = 30, 
                            frameon=True, 
                            save="streamline_{}.svg".format(full_name),
                            palette = colors)

    ##### Gene ranking
    scv.tl.rank_velocity_genes(merge_data, groupby='cell.annotation', min_corr=.3)
    df_gene_ranking = scv.DataFrame(merge_data.uns['rank_velocity_genes']['names'])
    df_gene_ranking.to_excel(f"./figures/{full_name}_gene_ranking.xlsx")

    ##### Pseudotime plot
    scv.tl.velocity_pseudotime(merge_data)
    scv.pl.scatter(merge_data, 
                   color='velocity_pseudotime', 
                   cmap='gnuplot', 
                   basis = "X_umap",
                   figsize = (15, 15), 
                   fontsize=20, 
                   legend_fontsize = 30, 
                   frameon=True, 
                   save="pseudotime_{}.svg".format(full_name),
                   palette = colors)

    ##### Speed and coherence
    scv.tl.velocity_confidence(merge_data)
    keys = 'velocity_length', 'velocity_confidence'
    scv.pl.scatter(merge_data, c=keys, cmap='coolwarm', perc=[5, 95], basis = "X_umap", frameon=True, 
                figsize = (10, 10), save="speed_coherence_{}.svg".format(full_name))

    df = merge_data.obs.groupby('cell.annotation')[keys].mean().T
    df.to_excel(f"./figures/{full_name}_speed_coherence.xlsx")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 import scanpy as sc
#       2 import numpy as np
#       3 import os
#
# File ~/miniconda3/envs/hieunguyen/lib/python3.10/site-packages/scanpy/__init__.py:14, in <module>
#      11 # the actual API
#      12 # (start with settings as several tools are using it)
#      13 from ._settings import settings, Verbosity
# ---> 14 from . import tools as tl
#      15 from . import preprocessing as pp
#      16 from . import plotting as pl
#
# File ~/miniconda3/envs/hieunguyen/lib/python3.10/site-packages/scanpy/tools/__init__.py:1, in <module>
# ----> 1 from ..preprocessing import pca
#       2 from ._tsne import tsne
#       3 from ._umap import umap
#
# File ~/miniconda3/envs/hieunguyen/lib/python3.10/site-packages/scanpy/preprocessing/__init__.py:1, in <module>
# ----> 1 from ._recipes import recipe_zheng17, recipe_weinreb17, recipe_seurat
#       2 from ._simple import filter_cells, filter_genes
#       3 from ._deprecated.highly_variable_genes import filter_genes_dispersion
#
# File ~/miniconda3/envs/hieunguyen/lib/python3.10/site-packages/scanpy/preprocessing/_recipes.py:12, in <module>
#       7 from .. import preprocessing as pp
#       8 from ._deprecated.highly_variable_genes import (
#       9     filter_genes_dispersion,
#      10     filter_genes_cv_deprecated,
#      11 )
# ---> 12 from ._normalization import normalize_total
#      13 from .. import logging as logg
#      14 from .._utils import AnyRandom
#
# File ~/miniconda3/envs/hieunguyen/lib/python3.10/site-packages/scanpy/preprocessing/_normalization.py:7, in <module>
#       5 from anndata import AnnData
#       6 from scipy.sparse import issparse
# ----> 7 from sklearn.utils import sparsefuncs
#       9 try:
#      10     from dask.array import Array as DaskArray
#
# File ~/miniconda3/envs/hieunguyen/lib/python3.10/site-packages/sklearn/__init__.py:82, in <module>
#      80 from . import _distributor_init  # noqa: F401
#      81 from . import __check_build  # noqa: F401
# ---> 82 from .base import clone
#      83 from .utils._show_versions import show_versions
#      85 __all__ = ['calibration', 'cluster', 'covariance', 'cross_decomposition',
#      86            'datasets', 'decomposition', 'dummy', 'ensemble', 'exceptions',
#      87            'experimental', 'externals', 'feature_extraction',
#    (...)
#      96            'clone', 'get_config', 'set_config', 'config_context',
#      97            'show_versions']
#
# File ~/miniconda3/envs/hieunguyen/lib/python3.10/site-packages/sklearn/base.py:17, in <module>
#      15 from . import __version__
#      16 from ._config import get_config
# ---> 17 from .utils import _IS_32BIT
#      18 from .utils._tags import (
#      19     _DEFAULT_TAGS,
#      20     _safe_tags,
#      21 )
#      22 from .utils.validation import check_X_y
#
# File ~/miniconda3/envs/hieunguyen/lib/python3.10/site-packages/sklearn/utils/__init__.py:23, in <module>
#      20 from scipy.sparse import issparse
#      22 from .murmurhash import murmurhash3_32
# ---> 23 from .class_weight import compute_class_weight, compute_sample_weight
#      24 from . import _joblib
#      25 from ..exceptions import DataConversionWarning
#
# File ~/miniconda3/envs/hieunguyen/lib/python3.10/site-packages/sklearn/utils/class_weight.py:7, in <module>
#       1 # Authors: Andreas Mueller
#       2 #          Manoj Kumar
#       3 # License: BSD 3 clause
#       5 import numpy as np
# ----> 7 from .validation import _deprecate_positional_args
#      10 @_deprecate_positional_args
#      11 def compute_class_weight(class_weight, *, classes, y):
#      12     """Estimate class weights for unbalanced datasets.
#      13
#      14     Parameters
#    (...)
#      38     Logistic Regression in Rare Events Data, King, Zen, 2001.
#      39     """
#
# File ~/miniconda3/envs/hieunguyen/lib/python3.10/site-packages/sklearn/utils/validation.py:26, in <module>
#      22 import joblib
#      24 from contextlib import suppress
# ---> 26 from .fixes import _object_dtype_isnan, parse_version
#      27 from .. import get_config as _get_config
#      28 from ..exceptions import PositiveSpectrumWarning
#
# File ~/miniconda3/envs/hieunguyen/lib/python3.10/site-packages/sklearn/utils/fixes.py:20, in <module>
#      18 import scipy.sparse as sp
#      19 import scipy
# ---> 20 import scipy.stats
#      21 from scipy.sparse.linalg import lsqr as sparse_lsqr  # noqa
#      22 from numpy.ma import MaskedArray as _MaskedArray  # TODO: remove in 1.0
#
# File ~/miniconda3/envs/hieunguyen/lib/python3.10/site-packages/scipy/stats/__init__.py:467, in <module>
#       1 """
#       2 .. _statsrefmanual:
#       3
#    (...)
#     462
#     463 """
#     465 from ._warnings_errors import (ConstantInputWarning, NearConstantInputWarning,
#     466                                DegenerateDataWarning, FitError)
# --> 467 from ._stats_py import *
#     468 from ._variation import variation
#     469 from .distributions import *
#
# File ~/miniconda3/envs/hieunguyen/lib/python3.10/site-packages/scipy/stats/_stats_py.py:46, in <module>
#      44 import scipy.special as special
#      45 from scipy import linalg
# ---> 46 from . import distributions
#      47 from . import _mstats_basic as mstats_basic
#      48 from ._stats_mstats_common import (_find_repeats, linregress, theilslopes,
#      49                                    siegelslopes)
#
# File ~/miniconda3/envs/hieunguyen/lib/python3.10/site-packages/scipy/stats/distributions.py:10, in <module>
#       1 #
#       2 # Author:  Travis Oliphant  2002-2011 with contributions from
#       3 #          SciPy Developers 2004-2011
#    (...)
#       6 #       instead of `git blame -Lxxx,+x`.
#       7 #
#       8 from ._distn_infrastructure import (rv_discrete, rv_continuous, rv_frozen)
# ---> 10 from . import _continuous_distns
#      11 from . import _discrete_distns
#      13 from ._continuous_distns import *
#
# File ~/miniconda3/envs/hieunguyen/lib/python3.10/site-packages/scipy/stats/_continuous_distns.py:1850, in <module>
#    1846     def _ppf(self, q, a, c):
#    1847         return (-sc.log1p(-q**(1.0/a)))**np.asarray(1.0/c)
# -> 1850 exponweib = exponweib_gen(a=0.0, name='exponweib')
#    1853 class exponpow_gen(rv_continuous):
#    1854     r"""An exponential power continuous random variable.
#    1855
#    1856     %(before_notes)s
#    (...)
#    1879
#    1880     """
#
# File ~/miniconda3/envs/hieunguyen/lib/python3.10/site-packages/scipy/stats/_distn_infrastructure.py:1925, in rv_continuous.__init__(self, momtype, a, b, xtol, badvalue, name, longname, shapes, extradoc, seed)
#    1922 self.shapes = shapes
#    1923 self.extradoc = extradoc
# -> 1925 self._construct_argparser(meths_to_inspect=[self._pdf, self._cdf],
#    1926                           locscale_in='loc=0, scale=1',
#    1927                           locscale_out='loc, scale')
#    1928 self._attach_methods()
#    1930 if longname is None:
#
# File ~/miniconda3/envs/hieunguyen/lib/python3.10/site-packages/scipy/stats/_distn_infrastructure.py:741, in rv_generic._construct_argparser(self, meths_to_inspect, locscale_in, locscale_out)
#     739 shapes_list = []
#     740 for meth in meths_to_inspect:
# --> 741     shapes_args = _getfullargspec(meth)  # NB does not contain self
#     742     args = shapes_args.args[1:]       # peel off 'x', too
#     744     if args:
#
# File ~/miniconda3/envs/hieunguyen/lib/python3.10/site-packages/scipy/_lib/_util.py:364, in getfullargspec_no_self(func)
#     343 def getfullargspec_no_self(func):
#     344     """inspect.getfullargspec replacement using inspect.signature.
#     345
#     346     If func is a bound method, do not list the 'self' parameter.
#    (...)
#     362
#     363     """
# --> 364     sig = inspect.signature(func)
#     365     args = [
#     366         p.name for p in sig.parameters.values()
#     367         if p.kind in [inspect.Parameter.POSITIONAL_OR_KEYWORD,
#     368                       inspect.Parameter.POSITIONAL_ONLY]
#     369     ]
#     370     varargs = [
#     371         p.name for p in sig.parameters.values()
#     372         if p.kind == inspect.Parameter.VAR_POSITIONAL
#     373     ]
#
# File ~/miniconda3/envs/hieunguyen/lib/python3.10/inspect.py:3247, in signature(obj, follow_wrapped, globals, locals, eval_str)
#    3245 def signature(obj, *, follow_wrapped=True, globals=None, locals=None, eval_str=False):
#    3246     """Get a signature object for the passed callable."""
# -> 3247     return Signature.from_callable(obj, follow_wrapped=follow_wrapped,
#    3248                                    globals=globals, locals=locals, eval_str=eval_str)
#
# File ~/miniconda3/envs/hieunguyen/lib/python3.10/inspect.py:2995, in Signature.from_callable(cls, obj, follow_wrapped, globals, locals, eval_str)
#    2991 @classmethod
#    2992 def from_callable(cls, obj, *,
#    2993                   follow_wrapped=True, globals=None, locals=None, eval_str=False):
#    2994     """Constructs Signature for the given callable object."""
# -> 2995     return _signature_from_callable(obj, sigcls=cls,
#    2996                                     follow_wrapper_chains=follow_wrapped,
#    2997                                     globals=globals, locals=locals, eval_str=eval_str)
#
# File ~/miniconda3/envs/hieunguyen/lib/python3.10/inspect.py:2397, in _signature_from_callable(obj, follow_wrapper_chains, skip_bound_arg, globals, locals, eval_str, sigcls)
#    2392     raise TypeError('{!r} is not a callable object'.format(obj))
#    2394 if isinstance(obj, types.MethodType):
#    2395     # In this case we skip the first parameter of the underlying
#    2396     # function (usually `self` or `cls`).
# -> 2397     sig = _get_signature_of(obj.__func__)
#    2399     if skip_bound_arg:
#    2400         return _signature_bound_method(sig)
#
# File ~/miniconda3/envs/hieunguyen/lib/python3.10/inspect.py:2456, in _signature_from_callable(obj, follow_wrapper_chains, skip_bound_arg, globals, locals, eval_str, sigcls)
#    2451             return sig.replace(parameters=new_params)
#    2453 if isfunction(obj) or _signature_is_functionlike(obj):
#    2454     # If it's a pure Python function, or an object that is duck type
#    2455     # of a Python function (Cython functions, for instance), then:
# -> 2456     return _signature_from_function(sigcls, obj,
#    2457                                     skip_bound_arg=skip_bound_arg,
#    2458                                     globals=globals, locals=locals, eval_str=eval_str)
#    2460 if _signature_is_builtin(obj):
#    2461     return _signature_from_builtin(sigcls, obj,
#    2462                                    skip_bound_arg=skip_bound_arg)
#
# File ~/miniconda3/envs/hieunguyen/lib/python3.10/inspect.py:2366, in _signature_from_function(cls, func, skip_bound_arg, globals, locals, eval_str)
#    2361     parameters.append(Parameter(name, annotation=annotation,
#    2362                                 kind=_VAR_KEYWORD))
#    2364 # Is 'func' is a pure Python function - don't validate the
#    2365 # parameters list (for correct order and defaults), it should be OK.
# -> 2366 return cls(parameters,
#    2367            return_annotation=annotations.get('return', _empty),
#    2368            __validate_parameters__=is_duck_function)
#
# File ~/miniconda3/envs/hieunguyen/lib/python3.10/inspect.py:2962, in Signature.__init__(self, parameters, return_annotation, __validate_parameters__)
#    2960             params[name] = param
#    2961     else:
# -> 2962         params = OrderedDict((param.name, param) for param in parameters)
#    2964 self._parameters = types.MappingProxyType(params)
#    2965 self._return_annotation = return_annotation
#
# KeyboardInterrupt:
